# %%
import ee

# %%
ee.Authenticate() 
ee.Initialize(project='ee-davidhansen896')

# %%
class Geoindexity:
    """
    The core geoindexity time series object. 
    ...

    Attributes
    ----------
    aoi : list
        [xmin, ymin, xmax, ymax]
    startdate : str
        'yyyy-mm-dd'
    enddate : str
        'yyyy-mm-dd'
    product: str 
        GEE data set: 'S1', 'S2_TOA', 'S2_SR' 
    cloudcover: int 
        percentage cloudcover threshold for series

    Methods
    -------
    fetch_data(self):
        Fetches GEE Image collection based on the following time_series attributes:
        product, aoi, startdate, enddate, cloudcover

    """
    # Will be changed accordingly to the config file parameters

    def __init__(self, aoi, startdate, enddate, product, cloudcover):
        data_dict = {
            'S2_TOA': 'COPERNICUS/S2_HARMONIZED',
            'Sentinel': 'COPERNICUS/S2_SR_HARMONIZED',
            'Landsat': 'LANDSAT/LC08/C02/T1_L2'}
        
        self.aoi = ee.Geometry.Rectangle(aoi)
        self.startdate = startdate
        self.enddate = enddate
        self.product = data_dict[product] 
        self.cloudcover = cloudcover
        self.collection = ee.ImageCollection(self.product).filterBounds(self.aoi).filterDate(self.startdate, self.enddate).filter(ee.Filter.lte('CLOUDY_PIXEL_PERCENTAGE', self.cloudcover))
    def __len__(self): 
        if self.collection != None:
            return self.collection.size().getInfo()
        else: 
            return 0

    def add_NDVI(self, image):
        if self.product == 'COPERNICUS/S2_SR_HARMONIZED':
            ndvi = image.expression( 
                '((nir - red)/(nir + red))',
                {'nir': image.select('B4'),
                 'red': image.select('B8')}
            ).rename('NDVI')
        elif self.product == 'LANDSAT/LC08/C02/T1_L2': 
            ndvi = image.expression( 
                '((nir - red)/(nir + red))',
                {'nir': image.select('SR_B5'),
                 'red': image.select('SR_B4')}
            ).rename('NDVI')      
            
        return image.addBands(ndvi)


    def add_EVI(self, image): 
        if self.product == 'COPERNICUS/S2_SR_HARMONIZED':
              evi = image.expression(
                '2.5 * ((nir – red) / (nir + 6 * red – 7.5 * blue + 1))',
                {'nir': img.select('B8'),
                 'red': img.select('B4'),
                 'blue': img.select('B2')}
              ).rename('EVI')

        elif self.product == 'LANDSAT/LC08/C02/T1_L2':
            evi = image.expression(
                '2.5 * ((nir – red) / (nir + 6 * red – 7.5 * blue + 1))',
                {'nir': img.select('SR_B5'),
                 'red': img.select('SR_B4'),
                 'blue': img.select('SR_B2')}
            ).rename('EVI')
        
        return image.addBands(evi)
        
    def ndvi_collection(self):
       return self.collection.map(self.add_NDVI) 

    def evi_collection(self):
        return self.collection.map(self.add_EVI)

# %%
aoi = [-2.9,
       47.48,
       -2.6,
       47.63
      ]


x = Geoindexity(aoi,
            startdate='2023-06-01',
            enddate='2023-08-30', 
            product= 'Sentinel', 
            cloudcover=10)

# %%
x.ndvi_collection().getInfo()['features']
# Out:
# [{'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 499980, 0, -60, 5300040]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'B8',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'B8A',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 499980, 0, -60, 5300040]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'B12',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'AOT',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'WVP',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'SCL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'TCI_R',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'TCI_G',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'TCI_B',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'MSK_CLDPRB',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'MSK_SNWPRB',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'QA10',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'QA20',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 4294967295},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'QA60',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 499980, 0, -60, 5300040]},
#    {'id': 'NDVI',
#     'data_type': {'type': 'PixelType', 'precision': 'float'},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]}],
#   'version': 1718623620924609,
#   'id': 'COPERNICUS/S2_SR_HARMONIZED/20230605T110619_20230605T111628_T30TWT',
#   'properties': {'SPACECRAFT_NAME': 'Sentinel-2B',
#    'SATURATED_DEFECTIVE_PIXEL_PERCENTAGE': 0,
#    'BOA_ADD_OFFSET_B12': -1000,
#    'CLOUD_SHADOW_PERCENTAGE': 0,
#    'system:footprint': {'type': 'LinearRing',
#     'coordinates': [[-3.0004004056528504, 47.853713059438725],
#      [-3.00040149768309, 47.85370186406999],
#      [-3.0003940191138065, 46.86587981752122],
#      [-3.0003405516212416, 46.8658383537243],
#      [-3.0002950314315644, 46.86579268461816],
#      [-3.0002734757247445, 46.86578984304678],
#      [-1.5601100823141425, 46.85673310060377],
#      [-1.560048449078021, 46.85676892482185],
#      [-1.5599807612999377, 46.856799209757014],
#      [-1.5599762846432563, 46.856813916189985],
#      [-1.5465962548082168, 47.350596971235056],
#      [-1.5328557500766538, 47.84432676466261],
#      [-1.5329090661701361, 47.844368876423786],
#      [-1.5329541395169877, 47.84441516902097],
#      [-1.5329760458620305, 47.84441826990207],
#      [-3.0002673673419116, 47.853791829789756],
#      [-3.000329138001284, 47.85375528471948],
#      [-3.000397284202068, 47.853724156827944],
#      [-3.0004004056528504, 47.853713059438725]]},
#    'SENSOR_QUALITY': 'PASSED',
#    'GENERATION_TIME': 1685974346000,
#    'CLOUDY_PIXEL_OVER_LAND_PERCENTAGE': 0.000986,
#    'CLOUD_COVERAGE_ASSESSMENT': 0.837602,
#    'THIN_CIRRUS_PERCENTAGE': 0.836072,
#    'GRANULE_MEAN_WV': 1.248432,
#    'BOA_ADD_OFFSET_B1': -1000,
#    'BOA_ADD_OFFSET_B2': -1000,
#    'DATASTRIP_ID': 'S2B_OPER_MSI_L2A_DS_2BPS_20230605T141226_S20230605T111628_N05.09',
#    'BOA_ADD_OFFSET_B5': -1000,
#    'BOA_ADD_OFFSET_B6': -1000,
#    'BOA_ADD_OFFSET_B3': -1000,
#    'BOA_ADD_OFFSET_B4': -1000,
#    'BOA_ADD_OFFSET_B9': -1000,
#    'BOA_ADD_OFFSET_B7': -1000,
#    'BOA_ADD_OFFSET_B8': -1000,
#    'GRANULE_ID': 'L2A_T30TWT_A032624_20230605T111628',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 223.882724172106,
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 218.385398679712,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 219.564523734088,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 218.983282387148,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 221.012329654671,
#    'NOT_VEGETATED_PERCENTAGE': 11.902817,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 220.35374639206,
#    'RADIOMETRIC_QUALITY': 'PASSED',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 225.453806087056,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 222.652506310215,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 218.627754081667,
#    'HIGH_PROBA_CLOUDS_PERCENTAGE': 0.000143,
#    'UNCLASSIFIED_PERCENTAGE': 0.223911,
#    'OZONE_SOURCE': 'AUX_ECMWFT',
#    'GRANULE_MEAN_AOT': 0.173735,
#    'BOA_ADD_OFFSET_B8A': -1000,
#    'SNOW_ICE_PERCENTAGE': 3e-06,
#    'BOA_ADD_OFFSET_B11': -1000,
#    'BOA_ADD_OFFSET_B10': -1000,
#    'GEOMETRIC_QUALITY': 'PASSED',
#    'system:asset_size': 1642815051,
#    'system:index': '20230605T110619_20230605T111628_T30TWT',
#    'DATATAKE_IDENTIFIER': 'GS2B_20230605T110619_032624_N05.09',
#    'AOT_RETRIEVAL_ACCURACY': 0,
#    'AOT_RETRIEVAL_METHOD': 'SEN2COR_DDV',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 218.629574788252,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 153.937056142402,
#    'VEGETATION_PERCENTAGE': 52.988416,
#    'SOLAR_IRRADIANCE_B12': 87.75,
#    'SOLAR_IRRADIANCE_B10': 365.41,
#    'SOLAR_IRRADIANCE_B11': 247.08,
#    'SOLAR_IRRADIANCE_B8A': 953.93,
#    'FORMAT_CORRECTNESS': 'PASSED',
#    'system:time_end': 1685963888953,
#    'WATER_VAPOUR_RETRIEVAL_ACCURACY': 0,
#    'OZONE_VALUE': 364.038363,
#    'system:time_start': 1685963888953,
#    'PROCESSING_BASELINE': '05.09',
#    'SENSING_ORBIT_NUMBER': 137,
#    'NODATA_PIXEL_PERCENTAGE': 0,
#    'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#    'GENERAL_QUALITY': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.972580970731567,
#    'MEDIUM_PROBA_CLOUDS_PERCENTAGE': 0.001387,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 3.5316261786376,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 3.21549935675053,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 3.14623638793939,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 3.03196832963749,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 2.93083517963165,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 3.62177022648785,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 2.97799321689476,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 3.35947631940326,
#    'DARK_FEATURES_PERCENTAGE': 0.008809,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 3.28623786134494,
#    'MEAN_SOLAR_ZENITH_ANGLE': 26.7222300501203,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 3.44085131843585,
#    'RADIATIVE_TRANSFER_ACCURACY': 0,
#    'MGRS_TILE': '30TWT',
#    'CLOUDY_PIXEL_PERCENTAGE': 0.837602,
#    'PRODUCT_ID': 'S2B_MSIL2A_20230605T110619_N0509_R137_T30TWT_20230605T141226',
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 3.11020878095621,
#    'SOLAR_IRRADIANCE_B9': 817.58,
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0.0004,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 3.27558911995892,
#    'L2A_QUALITY': 'PASSED',
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 3.46635835026047,
#    'SOLAR_IRRADIANCE_B6': 1291.13,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 221.05357909277,
#    'SOLAR_IRRADIANCE_B5': 1425.78,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 219.537283258455,
#    'SOLAR_IRRADIANCE_B8': 1041.28,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 218.747499440609,
#    'SOLAR_IRRADIANCE_B7': 1175.57,
#    'SOLAR_IRRADIANCE_B2': 1959.75,
#    'SOLAR_IRRADIANCE_B1': 1874.3,
#    'SOLAR_IRRADIANCE_B4': 1512.79,
#    'SOLAR_IRRADIANCE_B3': 1824.93,
#    'WATER_PERCENTAGE': 34.038439}},
#  {'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 399960, 0, -60, 5300040]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B8',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B8A',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 399960, 0, -60, 5300040]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B12',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'AOT',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'WVP',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'SCL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'TCI_R',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'TCI_G',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'TCI_B',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'MSK_CLDPRB',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'MSK_SNWPRB',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'QA10',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'QA20',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 4294967295},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'QA60',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 399960, 0, -60, 5300040]},
#    {'id': 'NDVI',
#     'data_type': {'type': 'PixelType', 'precision': 'float'},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]}],
#   'version': 1718623620924609,
#   'id': 'COPERNICUS/S2_SR_HARMONIZED/20230610T110621_20230610T111704_T30TVT',
#   'properties': {'SPACECRAFT_NAME': 'Sentinel-2A',
#    'SATURATED_DEFECTIVE_PIXEL_PERCENTAGE': 0,
#    'BOA_ADD_OFFSET_B12': -1000,
#    'CLOUD_SHADOW_PERCENTAGE': 0.679493,
#    'system:footprint': {'type': 'LinearRing',
#     'coordinates': [[-4.3124301621702665, 46.85826645162285],
#      [-4.312413652691263, 46.85826588743032],
#      [-2.8722050174719462, 46.86571850994973],
#      [-2.872144289379904, 46.865755042606104],
#      [-2.8720773999404137, 46.865786029768046],
#      [-2.8720732067786194, 46.86580086515929],
#      [-2.869662880868485, 47.85362784860023],
#      [-2.8697173199953494, 47.85366941985176],
#      [-2.8697635344965255, 47.853715119447614],
#      [-2.869785549084144, 47.85371796548627],
#      [-4.337137030283491, 47.84600483931417],
#      [-4.337197883682099, 47.845967505152394],
#      [-4.337265199381007, 47.84593566608445],
#      [-4.337268990261056, 47.845920798072086],
#      [-4.324743729544362, 47.35215642932248],
#      [-4.312547439084642, 46.85835434903425],
#      [-4.3124929982863724, 46.858313502126954],
#      [-4.312446372120219, 46.85826836061316],
#      [-4.3124301621702665, 46.85826645162285]]},
#    'SENSOR_QUALITY': 'PASSED',
#    'GENERATION_TIME': 1686423184000,
#    'CLOUDY_PIXEL_OVER_LAND_PERCENTAGE': 12.918139,
#    'CLOUD_COVERAGE_ASSESSMENT': 6.393781,
#    'THIN_CIRRUS_PERCENTAGE': 3.238562,
#    'GRANULE_MEAN_WV': 2.584544,
#    'BOA_ADD_OFFSET_B1': -1000,
#    'BOA_ADD_OFFSET_B2': -1000,
#    'DATASTRIP_ID': 'S2A_OPER_MSI_L2A_DS_2APS_20230610T185304_S20230610T111704_N05.09',
#    'BOA_ADD_OFFSET_B5': -1000,
#    'BOA_ADD_OFFSET_B6': -1000,
#    'BOA_ADD_OFFSET_B3': -1000,
#    'BOA_ADD_OFFSET_B4': -1000,
#    'BOA_ADD_OFFSET_B9': -1000,
#    'BOA_ADD_OFFSET_B7': -1000,
#    'BOA_ADD_OFFSET_B8': -1000,
#    'GRANULE_ID': 'L2A_T30TVT_A041604_20230610T111704',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 104.319898082005,
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 103.560733302568,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 103.73246492087,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 103.698673662994,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 103.905911102509,
#    'NOT_VEGETATED_PERCENTAGE': 1.577961,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 103.813192184525,
#    'RADIOMETRIC_QUALITY': 'PASSED',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 104.525114240501,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 104.135891415849,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 103.673148251134,
#    'HIGH_PROBA_CLOUDS_PERCENTAGE': 1.261097,
#    'UNCLASSIFIED_PERCENTAGE': 0.081854,
#    'OZONE_SOURCE': 'AUX_ECMWFT',
#    'GRANULE_MEAN_AOT': 0.088416,
#    'BOA_ADD_OFFSET_B8A': -1000,
#    'SNOW_ICE_PERCENTAGE': 0.00044500000000000003,
#    'BOA_ADD_OFFSET_B11': -1000,
#    'BOA_ADD_OFFSET_B10': -1000,
#    'GEOMETRIC_QUALITY': 'PASSED',
#    'system:asset_size': 1198665843,
#    'system:index': '20230610T110621_20230610T111704_T30TVT',
#    'DATATAKE_IDENTIFIER': 'GS2A_20230610T110621_041604_N05.09',
#    'AOT_RETRIEVAL_ACCURACY': 0,
#    'AOT_RETRIEVAL_METHOD': 'CAMS',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 103.645104739817,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 150.602862418108,
#    'VEGETATION_PERCENTAGE': 8.777283,
#    'SOLAR_IRRADIANCE_B12': 85.25,
#    'SOLAR_IRRADIANCE_B10': 367.15,
#    'SOLAR_IRRADIANCE_B11': 245.59,
#    'SOLAR_IRRADIANCE_B8A': 955.32,
#    'FORMAT_CORRECTNESS': 'PASSED',
#    'system:time_end': 1686395892146,
#    'WATER_VAPOUR_RETRIEVAL_ACCURACY': 0,
#    'OZONE_VALUE': 335.139651,
#    'system:time_start': 1686395892146,
#    'PROCESSING_BASELINE': '05.09',
#    'SENSING_ORBIT_NUMBER': 137,
#    'NODATA_PIXEL_PERCENTAGE': 0,
#    'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#    'GENERAL_QUALITY': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.971172052586922,
#    'MEDIUM_PROBA_CLOUDS_PERCENTAGE': 1.894121,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 5.9866278963376,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 5.80498278181256,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 5.76706716132777,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 5.70843351589934,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 5.65743403627824,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 6.036288126068,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 5.67891120240311,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 5.88706792507194,
#    'DARK_FEATURES_PERCENTAGE': 0.01002,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 5.84610494113758,
#    'MEAN_SOLAR_ZENITH_ANGLE': 26.7733766068106,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 5.93498925899389,
#    'RADIATIVE_TRANSFER_ACCURACY': 0,
#    'MGRS_TILE': '30TVT',
#    'CLOUDY_PIXEL_PERCENTAGE': 6.393781,
#    'PRODUCT_ID': 'S2A_MSIL2A_20230610T110621_N0509_R137_T30TVT_20230610T185304',
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 5.75430455077926,
#    'SOLAR_IRRADIANCE_B9': 812.92,
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0.0004,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 5.84156764935442,
#    'L2A_QUALITY': 'PASSED',
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 5.95516297483936,
#    'SOLAR_IRRADIANCE_B6': 1287.61,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 104.134979147437,
#    'SOLAR_IRRADIANCE_B5': 1424.64,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 103.889382405013,
#    'SOLAR_IRRADIANCE_B8': 1041.63,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 103.816362616878,
#    'SOLAR_IRRADIANCE_B7': 1162.08,
#    'SOLAR_IRRADIANCE_B2': 1959.66,
#    'SOLAR_IRRADIANCE_B1': 1884.69,
#    'SOLAR_IRRADIANCE_B4': 1512.06,
#    'SOLAR_IRRADIANCE_B3': 1823.24,
#    'WATER_PERCENTAGE': 82.479161}},
#  {'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 399960, 0, -60, 5300040]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B8',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B8A',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 399960, 0, -60, 5300040]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B12',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'AOT',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'WVP',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'SCL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'TCI_R',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'TCI_G',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'TCI_B',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'MSK_CLDPRB',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'MSK_SNWPRB',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'QA10',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'QA20',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 4294967295},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'QA60',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 399960, 0, -60, 5300040]},
#    {'id': 'NDVI',
#     'data_type': {'type': 'PixelType', 'precision': 'float'},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]}],
#   'version': 1718623620924609,
#   'id': 'COPERNICUS/S2_SR_HARMONIZED/20230615T110629_20230615T110637_T30TVT',
#   'properties': {'SPACECRAFT_NAME': 'Sentinel-2B',
#    'SATURATED_DEFECTIVE_PIXEL_PERCENTAGE': 0,
#    'BOA_ADD_OFFSET_B12': -1000,
#    'CLOUD_SHADOW_PERCENTAGE': 0,
#    'system:footprint': {'type': 'LinearRing',
#     'coordinates': [[-4.3124301621702665, 46.85826645162285],
#      [-4.312413652691263, 46.85826588743032],
#      [-2.8722050174719462, 46.86571850994973],
#      [-2.872144289379904, 46.865755042606104],
#      [-2.8720773999404137, 46.865786029768046],
#      [-2.8720732067786194, 46.86580086515929],
#      [-2.869662880868485, 47.85362784860023],
#      [-2.8697173199953494, 47.85366941985176],
#      [-2.8697635344965255, 47.853715119447614],
#      [-2.869785549084144, 47.85371796548627],
#      [-4.337137030283491, 47.84600483931417],
#      [-4.337197883682099, 47.845967505152394],
#      [-4.337265199381007, 47.84593566608445],
#      [-4.337268990261056, 47.845920798072086],
#      [-4.324743729544362, 47.35215642932248],
#      [-4.312547439084642, 46.85835434903425],
#      [-4.3124929982863724, 46.858313502126954],
#      [-4.312446372120219, 46.85826836061316],
#      [-4.3124301621702665, 46.85826645162285]]},
#    'SENSOR_QUALITY': 'PASSED',
#    'GENERATION_TIME': 1686837487000,
#    'CLOUDY_PIXEL_OVER_LAND_PERCENTAGE': 0.392117,
#    'CLOUD_COVERAGE_ASSESSMENT': 6.479938000000001,
#    'THIN_CIRRUS_PERCENTAGE': 1.070166,
#    'GRANULE_MEAN_WV': 1.977178,
#    'BOA_ADD_OFFSET_B1': -1000,
#    'BOA_ADD_OFFSET_B2': -1000,
#    'DATASTRIP_ID': 'S2B_OPER_MSI_L2A_DS_2BPS_20230615T135807_S20230615T110637_N05.09',
#    'BOA_ADD_OFFSET_B5': -1000,
#    'BOA_ADD_OFFSET_B6': -1000,
#    'BOA_ADD_OFFSET_B3': -1000,
#    'BOA_ADD_OFFSET_B4': -1000,
#    'BOA_ADD_OFFSET_B9': -1000,
#    'BOA_ADD_OFFSET_B7': -1000,
#    'BOA_ADD_OFFSET_B8': -1000,
#    'GRANULE_ID': 'L2A_T30TVT_A032767_20230615T110637',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 105.890107211015,
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 104.813423016933,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 105.132050634236,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 105.046606944888,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 105.35543873955,
#    'NOT_VEGETATED_PERCENTAGE': 1.808866,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 105.235310737534,
#    'RADIOMETRIC_QUALITY': 'PASSED',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 106.152413182966,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 105.671952643115,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 104.886599803614,
#    'HIGH_PROBA_CLOUDS_PERCENTAGE': 2.224472,
#    'UNCLASSIFIED_PERCENTAGE': 0.066785,
#    'OZONE_SOURCE': 'AUX_ECMWFT',
#    'GRANULE_MEAN_AOT': 0.309375,
#    'BOA_ADD_OFFSET_B8A': -1000,
#    'SNOW_ICE_PERCENTAGE': 3e-05,
#    'BOA_ADD_OFFSET_B11': -1000,
#    'BOA_ADD_OFFSET_B10': -1000,
#    'GEOMETRIC_QUALITY': 'PASSED',
#    'system:asset_size': 1374223540,
#    'system:index': '20230615T110629_20230615T110637_T30TVT',
#    'DATATAKE_IDENTIFIER': 'GS2B_20230615T110629_032767_N05.09',
#    'AOT_RETRIEVAL_ACCURACY': 0,
#    'AOT_RETRIEVAL_METHOD': 'CAMS',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 104.95871866098,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 149.872975443681,
#    'VEGETATION_PERCENTAGE': 10.864134,
#    'SOLAR_IRRADIANCE_B12': 87.75,
#    'SOLAR_IRRADIANCE_B10': 365.41,
#    'SOLAR_IRRADIANCE_B11': 247.08,
#    'SOLAR_IRRADIANCE_B8A': 953.93,
#    'FORMAT_CORRECTNESS': 'PASSED',
#    'system:time_end': 1686827893195,
#    'WATER_VAPOUR_RETRIEVAL_ACCURACY': 0,
#    'OZONE_VALUE': 338.765253,
#    'system:time_start': 1686827893195,
#    'PROCESSING_BASELINE': '05.09',
#    'SENSING_ORBIT_NUMBER': 137,
#    'NODATA_PIXEL_PERCENTAGE': 0,
#    'SENSING_ORBIT_DIRECTION': 'ASCENDING',
#    'GENERAL_QUALITY': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.969974212286044,
#    'MEDIUM_PROBA_CLOUDS_PERCENTAGE': 3.185301,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 6.0064968780164,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 5.82042732182666,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 5.78332343253131,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 5.72547801150131,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 5.67907280575076,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 6.0618774290057,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 5.69999161099535,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 5.90197075096287,
#    'DARK_FEATURES_PERCENTAGE': 0.023052,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 5.85760256333886,
#    'MEAN_SOLAR_ZENITH_ANGLE': 26.5829106466483,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 5.94962941217405,
#    'RADIATIVE_TRANSFER_ACCURACY': 0,
#    'MGRS_TILE': '30TVT',
#    'CLOUDY_PIXEL_PERCENTAGE': 6.479938,
#    'PRODUCT_ID': 'S2B_MSIL2A_20230615T110629_N0509_R137_T30TVT_20230615T135807',
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 5.7630841196513,
#    'SOLAR_IRRADIANCE_B9': 817.58,
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0.0215,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 5.85427271722632,
#    'L2A_QUALITY': 'PASSED',
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 5.96025933074144,
#    'SOLAR_IRRADIANCE_B6': 1291.13,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 105.49456882141,
#    'SOLAR_IRRADIANCE_B5': 1425.78,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 105.206318791484,
#    'SOLAR_IRRADIANCE_B8': 1041.28,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 104.971335326437,
#    'SOLAR_IRRADIANCE_B7': 1175.57,
#    'SOLAR_IRRADIANCE_B2': 1959.75,
#    'SOLAR_IRRADIANCE_B1': 1874.3,
#    'SOLAR_IRRADIANCE_B4': 1512.79,
#    'SOLAR_IRRADIANCE_B3': 1824.93,
#    'WATER_PERCENTAGE': 80.757195}},
#  {'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 499980, 0, -60, 5300040]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'B8',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'B8A',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 499980, 0, -60, 5300040]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'B12',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'AOT',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'WVP',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'SCL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'TCI_R',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'TCI_G',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'TCI_B',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'MSK_CLDPRB',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'MSK_SNWPRB',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'QA10',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]},
#    {'id': 'QA20',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 4294967295},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 499980, 0, -20, 5300040]},
#    {'id': 'QA60',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 499980, 0, -60, 5300040]},
#    {'id': 'NDVI',
#     'data_type': {'type': 'PixelType', 'precision': 'float'},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 499980, 0, -10, 5300040]}],
#   'version': 1718623620924609,
#   'id': 'COPERNICUS/S2_SR_HARMONIZED/20230615T110629_20230615T110637_T30TWT',
#   'properties': {'SPACECRAFT_NAME': 'Sentinel-2B',
#    'SATURATED_DEFECTIVE_PIXEL_PERCENTAGE': 0,
#    'BOA_ADD_OFFSET_B12': -1000,
#    'CLOUD_SHADOW_PERCENTAGE': 0.069008,
#    'system:footprint': {'type': 'LinearRing',
#     'coordinates': [[-3.0004004056528504, 47.853713059438725],
#      [-3.00040149768309, 47.85370186406999],
#      [-3.0003940191138065, 46.86587981752122],
#      [-3.0003405516212416, 46.8658383537243],
#      [-3.0002950314315644, 46.86579268461816],
#      [-3.0002734757247445, 46.86578984304678],
#      [-1.5601100823141425, 46.85673310060377],
#      [-1.560048449078021, 46.85676892482185],
#      [-1.5599807612999377, 46.856799209757014],
#      [-1.5599762846432563, 46.856813916189985],
#      [-1.5465962548082168, 47.350596971235056],
#      [-1.5328557500766538, 47.84432676466261],
#      [-1.5329090661701361, 47.844368876423786],
#      [-1.5329541395169877, 47.84441516902097],
#      [-1.5329760458620305, 47.84441826990207],
#      [-3.0002673673419116, 47.853791829789756],
#      [-3.000329138001284, 47.85375528471948],
#      [-3.000397284202068, 47.853724156827944],
#      [-3.0004004056528504, 47.853713059438725]]},
#    'SENSOR_QUALITY': 'PASSED',
#    'GENERATION_TIME': 1686837487000,
#    'CLOUDY_PIXEL_OVER_LAND_PERCENTAGE': 0.524896,
#    'CLOUD_COVERAGE_ASSESSMENT': 0.40021399999999996,
#    'THIN_CIRRUS_PERCENTAGE': 0.247176,
#    'GRANULE_MEAN_WV': 2.218301,
#    'BOA_ADD_OFFSET_B1': -1000,
#    'BOA_ADD_OFFSET_B2': -1000,
#    'DATASTRIP_ID': 'S2B_OPER_MSI_L2A_DS_2BPS_20230615T135807_S20230615T110637_N05.09',
#    'BOA_ADD_OFFSET_B5': -1000,
#    'BOA_ADD_OFFSET_B6': -1000,
#    'BOA_ADD_OFFSET_B3': -1000,
#    'BOA_ADD_OFFSET_B4': -1000,
#    'BOA_ADD_OFFSET_B9': -1000,
#    'BOA_ADD_OFFSET_B7': -1000,
#    'BOA_ADD_OFFSET_B8': -1000,
#    'GRANULE_ID': 'L2A_T30TWT_A032767_20230615T110637',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 223.755991396235,
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 218.28002673336,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 219.674383652502,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 219.236363431535,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 220.722232954697,
#    'NOT_VEGETATED_PERCENTAGE': 12.502341,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 220.063573999195,
#    'RADIOMETRIC_QUALITY': 'PASSED',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 225.336925792963,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 222.39119841007,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 218.359786311787,
#    'HIGH_PROBA_CLOUDS_PERCENTAGE': 0.024373,
#    'UNCLASSIFIED_PERCENTAGE': 0.24516500000000002,
#    'OZONE_SOURCE': 'AUX_ECMWFT',
#    'GRANULE_MEAN_AOT': 0.431587,
#    'BOA_ADD_OFFSET_B8A': -1000,
#    'SNOW_ICE_PERCENTAGE': 0,
#    'BOA_ADD_OFFSET_B11': -1000,
#    'BOA_ADD_OFFSET_B10': -1000,
#    'GEOMETRIC_QUALITY': 'PASSED',
#    'system:asset_size': 1684590047,
#    'system:index': '20230615T110629_20230615T110637_T30TWT',
#    'DATATAKE_IDENTIFIER': 'GS2B_20230615T110629_032767_N05.09',
#    'AOT_RETRIEVAL_ACCURACY': 0,
#    'AOT_RETRIEVAL_METHOD': 'SEN2COR_DDV',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 218.885067415457,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 152.405753896365,
#    'VEGETATION_PERCENTAGE': 51.755899,
#    'SOLAR_IRRADIANCE_B12': 87.75,
#    'SOLAR_IRRADIANCE_B10': 365.41,
#    'SOLAR_IRRADIANCE_B11': 247.08,
#    'SOLAR_IRRADIANCE_B8A': 953.93,
#    'FORMAT_CORRECTNESS': 'PASSED',
#    'system:time_end': 1686827889438,
#    'WATER_VAPOUR_RETRIEVAL_ACCURACY': 0,
#    'OZONE_VALUE': 340.057439,
#    'system:time_start': 1686827889438,
#    'PROCESSING_BASELINE': '05.09',
#    'SENSING_ORBIT_NUMBER': 137,
#    'NODATA_PIXEL_PERCENTAGE': 0,
#    'SENSING_ORBIT_DIRECTION': 'ASCENDING',
#    'GENERAL_QUALITY': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.969974212286044,
#    'MEDIUM_PROBA_CLOUDS_PERCENTAGE': 0.128666,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 3.53007226106398,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 3.21015620274228,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 3.14085355727219,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 3.02637208544891,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 2.9301129000448,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 3.62140063573163,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 2.97728024340745,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 3.36294306995945,
#    'DARK_FEATURES_PERCENTAGE': 0.018318,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 3.28523548378659,
#    'MEAN_SOLAR_ZENITH_ANGLE': 26.1535721698688,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 3.44417927979828,
#    'RADIATIVE_TRANSFER_ACCURACY': 0,
#    'MGRS_TILE': '30TWT',
#    'CLOUDY_PIXEL_PERCENTAGE': 0.400214,
#    'PRODUCT_ID': 'S2B_MSIL2A_20230615T110629_N0509_R137_T30TWT_20230615T135807',
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 3.10782279421629,
#    'SOLAR_IRRADIANCE_B9': 817.58,
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0.0003,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 3.27287504904225,
#    'L2A_QUALITY': 'PASSED',
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 3.46228240192282,
#    'SOLAR_IRRADIANCE_B6': 1291.13,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 221.027446044843,
#    'SOLAR_IRRADIANCE_B5': 1425.78,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 219.560232807502,
#    'SOLAR_IRRADIANCE_B8': 1041.28,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 218.634814125216,
#    'SOLAR_IRRADIANCE_B7': 1175.57,
#    'SOLAR_IRRADIANCE_B2': 1959.75,
#    'SOLAR_IRRADIANCE_B1': 1874.3,
#    'SOLAR_IRRADIANCE_B4': 1512.79,
#    'SOLAR_IRRADIANCE_B3': 1824.93,
#    'WATER_PERCENTAGE': 35.009053}},
#  {'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 399960, 0, -60, 5300040]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B8',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B8A',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 399960, 0, -60, 5300040]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B12',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'AOT',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'WVP',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'SCL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'TCI_R',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'TCI_G',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'TCI_B',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'MSK_CLDPRB',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'MSK_SNWPRB',
# ...
#    'system:footprint': {'type': 'LinearRing',
#     'coordinates': [[-3.0004004056528504, 47.853713059438725],
#      [-3.00040149768309, 47.85370186406999],
#      [-3.0003940191138065, 46.86587981752122],
#      [-3.0003405516212416, 46.8658383537243],
#      [-3.0002950314315644, 46.86579268461816],
#      [-3.0002734757247445, 46.86578984304678],
#      [-1.5601100823141425, 46.85673310060377],
#      [-1.560048449078021, 46.85676892482185],
#      [-1.5599807612999377, 46.856799209757014],
#      [-1.5599762846432563, 46.856813916189985],
#      [-1.5465962548082168, 47.350596971235056],
#      [-1.5328557500766538, 47.84432676466261],
#      [-1.5329090661701361, 47.844368876423786],
#      [-1.5329541395169877, 47.84441516902097],
#      [-1.5329760458620305, 47.84441826990207],
#      [-3.0002673673419116, 47.853791829789756],
#      [-3.000329138001284, 47.85375528471948],
#      [-3.000397284202068, 47.853724156827944],
#      [-3.0004004056528504, 47.853713059438725]]},
#    'SENSOR_QUALITY': 'PASSED',
#    'GENERATION_TIME': 1687696508000,
#    'CLOUDY_PIXEL_OVER_LAND_PERCENTAGE': 1.140664,
#    'CLOUD_COVERAGE_ASSESSMENT': 1.347179,
#    'THIN_CIRRUS_PERCENTAGE': 0.001974,
#    'GRANULE_MEAN_WV': 2.19838,
#    'BOA_ADD_OFFSET_B1': -1000,
#    'BOA_ADD_OFFSET_B2': -1000,
#    'DATASTRIP_ID': 'S2B_OPER_MSI_L2A_DS_2BPS_20230625T123508_S20230625T110839_N05.09',
#    'BOA_ADD_OFFSET_B5': -1000,
#    'BOA_ADD_OFFSET_B6': -1000,
#    'BOA_ADD_OFFSET_B3': -1000,
#    'BOA_ADD_OFFSET_B4': -1000,
#    'BOA_ADD_OFFSET_B9': -1000,
#    'BOA_ADD_OFFSET_B7': -1000,
#    'BOA_ADD_OFFSET_B8': -1000,
#    'GRANULE_ID': 'L2A_T30TWT_A032910_20230625T110839',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 223.599544313908,
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 218.118262325351,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 219.492159348837,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 219.050363058784,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 220.693598639283,
#    'NOT_VEGETATED_PERCENTAGE': 15.193188,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 220.024505716751,
#    'RADIOMETRIC_QUALITY': 'PASSED',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 225.068809970994,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 222.594863707621,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 218.364644370221,
#    'HIGH_PROBA_CLOUDS_PERCENTAGE': 0.500878,
#    'UNCLASSIFIED_PERCENTAGE': 0.348486,
#    'OZONE_SOURCE': 'AUX_ECMWFT',
#    'GRANULE_MEAN_AOT': 0.143905,
#    'BOA_ADD_OFFSET_B8A': -1000,
#    'SNOW_ICE_PERCENTAGE': 0,
#    'BOA_ADD_OFFSET_B11': -1000,
#    'BOA_ADD_OFFSET_B10': -1000,
#    'GEOMETRIC_QUALITY': 'PASSED',
#    'system:asset_size': 1622844172,
#    'system:index': '20230625T110619_20230625T110839_T30TWT',
#    'DATATAKE_IDENTIFIER': 'GS2B_20230625T110619_032910_N05.09',
#    'AOT_RETRIEVAL_ACCURACY': 0,
#    'AOT_RETRIEVAL_METHOD': 'SEN2COR_DDV',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 218.695370297406,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 151.277598099959,
#    'VEGETATION_PERCENTAGE': 48.134479,
#    'SOLAR_IRRADIANCE_B12': 87.75,
#    'SOLAR_IRRADIANCE_B10': 365.41,
#    'SOLAR_IRRADIANCE_B11': 247.08,
#    'SOLAR_IRRADIANCE_B8A': 953.93,
#    'FORMAT_CORRECTNESS': 'PASSED',
#    'system:time_end': 1687691888922,
#    'WATER_VAPOUR_RETRIEVAL_ACCURACY': 0,
#    'OZONE_VALUE': 310.72847,
#    'system:time_start': 1687691888922,
#    'PROCESSING_BASELINE': '05.09',
#    'SENSING_ORBIT_NUMBER': 137,
#    'NODATA_PIXEL_PERCENTAGE': 0,
#    'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#    'GENERAL_QUALITY': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.968241111750287,
#    'MEDIUM_PROBA_CLOUDS_PERCENTAGE': 0.844327,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 3.52455383279895,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 3.20626638897453,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 3.13705520228327,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 3.02454585028608,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 2.92028735162129,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 3.61468712165978,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 2.96907931179603,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 3.35752567413106,
#    'DARK_FEATURES_PERCENTAGE': 0.009549,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 3.27985516094755,
#    'MEAN_SOLAR_ZENITH_ANGLE': 26.2541142211509,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 3.43873536706172,
#    'RADIATIVE_TRANSFER_ACCURACY': 0,
#    'MGRS_TILE': '30TWT',
#    'CLOUDY_PIXEL_PERCENTAGE': 1.347179,
#    'PRODUCT_ID': 'S2B_MSIL2A_20230625T110619_N0509_R137_T30TWT_20230625T123508',
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 3.10286476243354,
#    'SOLAR_IRRADIANCE_B9': 817.58,
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0.0002,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 3.26536021625555,
#    'L2A_QUALITY': 'PASSED',
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 3.45497725387655,
#    'SOLAR_IRRADIANCE_B6': 1291.13,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 221.158705228017,
#    'SOLAR_IRRADIANCE_B5': 1425.78,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 219.269277568833,
#    'SOLAR_IRRADIANCE_B8': 1041.28,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 218.347506923952,
#    'SOLAR_IRRADIANCE_B7': 1175.57,
#    'SOLAR_IRRADIANCE_B2': 1959.75,
#    'SOLAR_IRRADIANCE_B1': 1874.3,
#    'SOLAR_IRRADIANCE_B4': 1512.79,
#    'SOLAR_IRRADIANCE_B3': 1824.93,
#    'WATER_PERCENTAGE': 34.433341}},
#  {'type': 'Image',
#   'bands': [{'id': 'B1',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 399960, 0, -60, 5300040]},
#    {'id': 'B2',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B3',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B4',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B5',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B6',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B7',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B8',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'B8A',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B9',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 399960, 0, -60, 5300040]},
#    {'id': 'B11',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'B12',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'AOT',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'WVP',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'SCL',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'TCI_R',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'TCI_G',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'TCI_B',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'MSK_CLDPRB',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'MSK_SNWPRB',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 255},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'QA10',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]},
#    {'id': 'QA20',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 4294967295},
#     'dimensions': [5490, 5490],
#     'crs': 'EPSG:32630',
#     'crs_transform': [20, 0, 399960, 0, -20, 5300040]},
#    {'id': 'QA60',
#     'data_type': {'type': 'PixelType',
#      'precision': 'int',
#      'min': 0,
#      'max': 65535},
#     'dimensions': [1830, 1830],
#     'crs': 'EPSG:32630',
#     'crs_transform': [60, 0, 399960, 0, -60, 5300040]},
#    {'id': 'NDVI',
#     'data_type': {'type': 'PixelType', 'precision': 'float'},
#     'dimensions': [10980, 10980],
#     'crs': 'EPSG:32630',
#     'crs_transform': [10, 0, 399960, 0, -10, 5300040]}],
#   'version': 1718623620924609,
#   'id': 'COPERNICUS/S2_SR_HARMONIZED/20230819T110621_20230819T111706_T30TVT',
#   'properties': {'SPACECRAFT_NAME': 'Sentinel-2A',
#    'SATURATED_DEFECTIVE_PIXEL_PERCENTAGE': 0,
#    'BOA_ADD_OFFSET_B12': -1000,
#    'CLOUD_SHADOW_PERCENTAGE': 2.004652,
#    'system:footprint': {'type': 'LinearRing',
#     'coordinates': [[-4.3124301621702665, 46.85826645162285],
#      [-4.312413652691263, 46.85826588743032],
#      [-2.8722050174719462, 46.86571850994973],
#      [-2.872144289379904, 46.865755042606104],
#      [-2.8720773999404137, 46.865786029768046],
#      [-2.8720732067786194, 46.86580086515929],
#      [-2.869662880868485, 47.85362784860023],
#      [-2.8697173199953494, 47.85366941985176],
#      [-2.8697635344965255, 47.853715119447614],
#      [-2.869785549084144, 47.85371796548627],
#      [-4.337137030283491, 47.84600483931417],
#      [-4.337197883682099, 47.845967505152394],
#      [-4.337265199381007, 47.84593566608445],
#      [-4.337268990261056, 47.845920798072086],
#      [-4.324743729544362, 47.35215642932248],
#      [-4.312547439084642, 46.85835434903425],
#      [-4.3124929982863724, 46.858313502126954],
#      [-4.312446372120219, 46.85826836061316],
#      [-4.3124301621702665, 46.85826645162285]]},
#    'SENSOR_QUALITY': 'PASSED',
#    'GENERATION_TIME': 1692458697000,
#    'CLOUDY_PIXEL_OVER_LAND_PERCENTAGE': 28.881589,
#    'CLOUD_COVERAGE_ASSESSMENT': 4.41533,
#    'THIN_CIRRUS_PERCENTAGE': 0.000325,
#    'GRANULE_MEAN_WV': 1.745891,
#    'BOA_ADD_OFFSET_B1': -1000,
#    'BOA_ADD_OFFSET_B2': -1000,
#    'DATASTRIP_ID': 'S2A_OPER_MSI_L2A_DS_2APS_20230819T152457_S20230819T111706_N05.09',
#    'BOA_ADD_OFFSET_B5': -1000,
#    'BOA_ADD_OFFSET_B6': -1000,
#    'BOA_ADD_OFFSET_B3': -1000,
#    'BOA_ADD_OFFSET_B4': -1000,
#    'BOA_ADD_OFFSET_B9': -1000,
#    'BOA_ADD_OFFSET_B7': -1000,
#    'BOA_ADD_OFFSET_B8': -1000,
#    'GRANULE_ID': 'L2A_T30TVT_A042605_20230819T111706',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8': 104.245487240432,
#    'DATATAKE_TYPE': 'INS-NOBS',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B9': 103.497982133892,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B6': 103.621585516428,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B7': 103.561167927406,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B4': 103.797242778173,
#    'NOT_VEGETATED_PERCENTAGE': 1.030252,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B5': 103.711290691106,
#    'RADIOMETRIC_QUALITY': 'PASSED',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B2': 104.489699016424,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B3': 104.065136292061,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B1': 103.522263819969,
#    'HIGH_PROBA_CLOUDS_PERCENTAGE': 2.129084,
#    'UNCLASSIFIED_PERCENTAGE': 0.112458,
#    'OZONE_SOURCE': 'AUX_ECMWFT',
#    'GRANULE_MEAN_AOT': 0.058416,
#    'BOA_ADD_OFFSET_B8A': -1000,
#    'SNOW_ICE_PERCENTAGE': 0.01503,
#    'BOA_ADD_OFFSET_B11': -1000,
#    'BOA_ADD_OFFSET_B10': -1000,
#    'GEOMETRIC_QUALITY': 'PASSED',
#    'system:asset_size': 1087705924,
#    'system:index': '20230819T110621_20230819T111706_T30TVT',
#    'DATATAKE_IDENTIFIER': 'GS2A_20230819T110621_042605_N05.09',
#    'AOT_RETRIEVAL_ACCURACY': 0,
#    'AOT_RETRIEVAL_METHOD': 'CAMS',
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B8A': 103.499380392355,
#    'MEAN_SOLAR_AZIMUTH_ANGLE': 155.136385660534,
#    'VEGETATION_PERCENTAGE': 6.103404000000001,
#    'SOLAR_IRRADIANCE_B12': 85.25,
#    'SOLAR_IRRADIANCE_B10': 367.15,
#    'SOLAR_IRRADIANCE_B11': 245.59,
#    'SOLAR_IRRADIANCE_B8A': 955.32,
#    'FORMAT_CORRECTNESS': 'PASSED',
#    'system:time_end': 1692443894328,
#    'WATER_VAPOUR_RETRIEVAL_ACCURACY': 0,
#    'OZONE_VALUE': 288.051745,
#    'system:time_start': 1692443894328,
#    'PROCESSING_BASELINE': '05.09',
#    'SENSING_ORBIT_NUMBER': 137,
#    'NODATA_PIXEL_PERCENTAGE': 0,
#    'SENSING_ORBIT_DIRECTION': 'DESCENDING',
#    'GENERAL_QUALITY': 'PASSED',
#    'REFLECTANCE_CONVERSION_CORRECTION': 0.975109304046162,
#    'MEDIUM_PROBA_CLOUDS_PERCENTAGE': 2.285921,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B1': 5.9691168157838,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B5': 5.77901871449965,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B4': 5.74133319413758,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B3': 5.68177429333134,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B2': 5.64033754983268,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B9': 6.02134109356201,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8': 5.65563361170192,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B7': 5.86531755405699,
#    'DARK_FEATURES_PERCENTAGE': 0.003248,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B6': 5.82041442800577,
#    'MEAN_SOLAR_ZENITH_ANGLE': 36.7910673721665,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B8A': 5.92784868016413,
#    'RADIATIVE_TRANSFER_ACCURACY': 0,
#    'MGRS_TILE': '30TVT',
#    'CLOUDY_PIXEL_PERCENTAGE': 4.41533,
#    'PRODUCT_ID': 'S2A_MSIL2A_20230819T110621_N0509_R137_T30TVT_20230819T152457',
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B10': 5.72729362072812,
#    'SOLAR_IRRADIANCE_B9': 812.92,
#    'DEGRADED_MSI_DATA_PERCENTAGE': 0,
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B11': 5.82555972130395,
#    'L2A_QUALITY': 'PASSED',
#    'MEAN_INCIDENCE_ZENITH_ANGLE_B12': 5.94391529340009,
#    'SOLAR_IRRADIANCE_B6': 1287.61,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B10': 104.074341506999,
#    'SOLAR_IRRADIANCE_B5': 1424.64,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B11': 103.852979997833,
#    'SOLAR_IRRADIANCE_B8': 1041.63,
#    'MEAN_INCIDENCE_AZIMUTH_ANGLE_B12': 103.717920078326,
#    'SOLAR_IRRADIANCE_B7': 1162.08,
#    'SOLAR_IRRADIANCE_B2': 1959.66,
#    'SOLAR_IRRADIANCE_B1': 1884.69,
#    'SOLAR_IRRADIANCE_B4': 1512.06,
#    'SOLAR_IRRADIANCE_B3': 1823.24,
#    'WATER_PERCENTAGE': 86.315626}}]

# %%
x.fetch_dat

# %%
x.collection.map(x.add_NDVI)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 x.collection.map(x.add_NDVI)
#
# File ~\anaconda3\envs\gee_test\Lib\site-packages\ee\_utils.py:38, in accept_opt_prefix.<locals>.opt_fixed.<locals>.wrapper(*args, **kwargs)
#      36     if new_key not in kwargs:
#      37       kwargs[new_key] = old_key_val
# ---> 38 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\gee_test\Lib\site-packages\ee\collection.py:245, in Collection.map(self, algorithm, dropNulls)
#     242 element_type = self.elementType()
#     243 with_cast = lambda e: algorithm(element_type(e, None))
#     244 return self._cast(
# --> 245     apifunction.ApiFunction.call_(
#     246         'Collection.map', self, with_cast, dropNulls
#     247     )
#     248 )
#
# File ~\anaconda3\envs\gee_test\Lib\site-packages\ee\apifunction.py:84, in ApiFunction.call_(cls, name, *args, **kwargs)
#      71 @classmethod
#      72 def call_(cls, name: str, *args: Any, **kwargs: Any) -> Any:
#      73   """Call a named API function with positional and keyword arguments.
#      74
#      75   Args:
#    (...)
#      82     a recognized return type, the returned value will be cast to that type.
#      83   """
# ---> 84   return cls.lookup(name).call(*args, **kwargs)
#
# File ~\anaconda3\envs\gee_test\Lib\site-packages\ee\function.py:62, in Function.call(self, *args, **kwargs)
#      50 def call(self, *args, **kwargs):
#      51   """Calls the function with the given positional and keyword arguments.
#      52
#      53   Args:
#    (...)
#      60     to that type.
#      61   """
# ---> 62   return self.apply(self.nameArgs(args, kwargs))
#
# File ~\anaconda3\envs\gee_test\Lib\site-packages\ee\function.py:75, in Function.apply(self, named_args)
#      64 def apply(self, named_args):
#      65   """Calls the function with a dictionary of named arguments.
#      66
#      67   Args:
#    (...)
#      73     to that type.
#      74   """
# ---> 75   result = computedobject.ComputedObject(self, self.promoteArgs(named_args))
#      76   return Function._promoter(result, self.getReturnType())
#
# File ~\anaconda3\envs\gee_test\Lib\site-packages\ee\function.py:103, in Function.promoteArgs(self, args)
#     101 name = arg_spec['name']
#     102 if name in args:
# --> 103   promoted_args[name] = Function._promoter(args[name], arg_spec['type'])
#     104 elif not arg_spec.get('optional'):
#     105   raise ee_exception.EEException(
#     106       'Required argument (%s) missing to function: %s'
#     107       % (name, signature.get('name')))
#
# File ~\anaconda3\envs\gee_test\Lib\site-packages\ee\__init__.py:328, in _Promote(arg, a_class)
#     325 elif callable(arg):
#     326   # A native function that needs to be wrapped.
#     327   args_count = len(inspect.getfullargspec(arg).args)
# --> 328   return CustomFunction.create(arg, 'Object', ['Object'] * args_count)
#     329 elif isinstance(arg, Encodable):
#     330   # An ee.Function or a computed function like the return value of
#     331   # Image.parseExpression().
#     332   return arg
#
# File ~\anaconda3\envs\gee_test\Lib\site-packages\ee\customfunction.py:126, in CustomFunction.create(func, return_type, arg_types)
#     120 args = [{'name': None, 'type': StringifyType(i)} for i in arg_types]
#     121 signature = {
#     122     'name': '',
#     123     'returns': StringifyType(return_type),
#     124     'args': args
#     125 }
# --> 126 return CustomFunction(signature, func)
#
# File ~\anaconda3\envs\gee_test\Lib\site-packages\ee\customfunction.py:40, in CustomFunction.__init__(self, signature, body)
#      26 """Creates a function defined by a given expression with unbound variables.
#      27
#      28 The expression is created by evaluating the given function
#    (...)
#      35   body: The Python function to evaluate.
#      36 """
#      37 variables = [CustomFunction.variable(arg['type'], arg['name'])
#      38              for arg in signature['args']]
# ---> 40 if body(*variables) is None:
#      41   raise ee_exception.EEException('User-defined methods must return a value')
#      43 # The signature of the function.
#
# File ~\anaconda3\envs\gee_test\Lib\site-packages\ee\collection.py:243, in Collection.map.<locals>.<lambda>(e)
#     225 """Maps an algorithm over a collection.
#     226
#     227 Args:
#    (...)
#     240   ee_exception.EEException: if algorithm is not a function.
#     241 """
#     242 element_type = self.elementType()
# --> 243 with_cast = lambda e: algorithm(element_type(e, None))
#     244 return self._cast(
#     245     apifunction.ApiFunction.call_(
#     246         'Collection.map', self, with_cast, dropNulls
#     247     )
#     248 )
#
# TypeError: Geoindexity.add_NDVI() takes 1 positional argument but 2 were given
