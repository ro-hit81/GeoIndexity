# %%
import sys
sys.path.append('../geoindexity')

# %%
from geoindexity import Landsat, Sentinel

# %%
from config import *

# %%
Landsat(roi, start_date, end_date, collection_id, properties).select_product()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Landsat(roi, start_date, end_date, collection_id, properties).select_product()
#
# File ~/Library/CloudStorage/OneDrive-UniversitätSalzburg/Classes/2nd semester/Software Development/Project/GeoIndexity/test/../geoindexity/geoindexity.py:23, in Landsat.select_product(self)
#      21     for property_name, value in self.properties.items():
#      22         if property_name not in valid_properties:
# ---> 23             raise KeyError(f"Invalid property name: {property_name}. Supported properties: {', '.join(valid_properties.keys())}.")
#      24         image_collection=image_collection.filter(ee.Filter.lte(property_name, value))
#      25 return image_collection
#
# KeyError: 'Invalid property name: me. Supported properties: CLOUD_COVER, CLOUD_LAND_COVER.'

# %%
Sentinel(roi, start_date, end_date, collection_id, properties).select_product()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Sentinel(roi, start_date, end_date, collection_id, properties).select_product()
#
# File ~/Library/CloudStorage/OneDrive-UniversitätSalzburg/Classes/2nd semester/Software Development/Project/GeoIndexity/test/../geoindexity/geoindexity.py:63, in Sentinel.select_product(self)
#      61     for property_name, value in self.properties.items():
#      62         if property_name not in valid_properties:
# ---> 63             raise KeyError(f"Invalid property name: {property_name}. Supported properties: {', '.join(valid_properties.keys())}.")
#      64         image_collection=image_collection.filter(ee.Filter.lte(property_name, value))
#      65 return image_collection
#
# ...

# %%
Sentinel(roi, start_date, end_date, collection_id).select_product().getInfo()
# Out:
# {'type': 'ImageCollection',
#  'bands': [{'id': 'B1',
#    'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B2', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B3', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B4', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B5', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B6', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B7', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B8', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B9', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B10', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B11', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'QA_PIXEL',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
# ...

# %%
Landsat(roi, start_date, end_date, collection_id).number_of_images()
# Out:
# Total Landsat images collected: 10

# %%
Landsat(roi, start_date, end_date, collection_id).select_product().getInfo()
# Out:
# {'type': 'ImageCollection',
#  'bands': [{'id': 'B1',
#    'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B2', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B3', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B4', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B5', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B6', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B7', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B8', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B9', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B10', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'B11', 'data_type': {'type': 'PixelType', 'precision': 'float'}},
#   {'id': 'QA_PIXEL',
#    'data_type': {'type': 'PixelType',
#     'precision': 'int',
#     'min': 0,
# ...

# %%
Sentinel(roi, start_date, end_date, collection_id).number_of_images()
# Out:
# Total Sentinel images collected: 10
